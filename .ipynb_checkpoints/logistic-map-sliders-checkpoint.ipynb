# %%
# !pip install matplotlib
# !pip install numpy
# !pip install ipythonwidgets
# !pip install ipython
# Out:
# Requirement already satisfied: matplotlib in c:\users\paulk\.pyenv\pyenv-win\versions\3.13.3\lib\site-packages (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\paulk\.pyenv\pyenv-win\versions\3.13.3\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\paulk\.pyenv\pyenv-win\versions\3.13.3\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\paulk\.pyenv\pyenv-win\versions\3.13.3\lib\site-packages (from matplotlib) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\paulk\.pyenv\pyenv-win\versions\3.13.3\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\paulk\.pyenv\pyenv-win\versions\3.13.3\lib\site-packages (from matplotlib) (2.3.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\paulk\.pyenv\pyenv-win\versions\3.13.3\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\paulk\.pyenv\pyenv-win\versions\3.13.3\lib\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\paulk\.pyenv\pyenv-win\versions\3.13.3\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\paulk\.pyenv\pyenv-win\versions\3.13.3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\paulk\.pyenv\pyenv-win\versions\3.13.3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\paulk\.pyenv\pyenv-win\versions\3.13.3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\paulk\.pyenv\pyenv-win\versions\3.13.3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\paulk\.pyenv\pyenv-win\versions\3.13.3\Lib\site-packages)
#
# [notice] A new release of pip is available: 25.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy in c:\users\paulk\.pyenv\pyenv-win\versions\3.13.3\lib\site-packages (2.3.0)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\paulk\.pyenv\pyenv-win\versions\3.13.3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\paulk\.pyenv\pyenv-win\versions\3.13.3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\paulk\.pyenv\pyenv-win\versions\3.13.3\Lib\site-packages)
#
# [notice] A new release of pip is available: 25.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# WARNING: Ignoring invalid distribution ~andas (C:\Users\paulk\.pyenv\pyenv-win\versions\3.13.3\Lib\site-packages)
# ERROR: Could not find a version that satisfies the requirement ipythonwidgets (from versions: none)
#
# [notice] A new release of pip is available: 25.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for ipythonwidgets
# Requirement already satisfied: ipython in c:\users\paulk\.pyenv\pyenv-win\versions\3.13.3\lib\site-packages (9.3.0)
# Requirement already satisfied: colorama in c:\users\paulk\.pyenv\pyenv-win\versions\3.13.3\lib\site-packages (from ipython) (0.4.6)
# Requirement already satisfied: decorator in c:\users\paulk\.pyenv\pyenv-win\versions\3.13.3\lib\site-packages (from ipython) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\paulk\.pyenv\pyenv-win\versions\3.13.3\lib\site-packages (from ipython) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\paulk\.pyenv\pyenv-win\versions\3.13.3\lib\site-packages (from ipython) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\paulk\.pyenv\pyenv-win\versions\3.13.3\lib\site-packages (from ipython) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\paulk\.pyenv\pyenv-win\versions\3.13.3\lib\site-packages (from ipython) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\paulk\.pyenv\pyenv-win\versions\3.13.3\lib\site-packages (from ipython) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\paulk\.pyenv\pyenv-win\versions\3.13.3\lib\site-packages (from ipython) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\paulk\.pyenv\pyenv-win\versions\3.13.3\lib\site-packages (from ipython) (5.14.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\paulk\.pyenv\pyenv-win\versions\3.13.3\lib\site-packages (from jedi>=0.16->ipython) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\paulk\.pyenv\pyenv-win\versions\3.13.3\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\paulk\.pyenv\pyenv-win\versions\3.13.3\lib\site-packages (from stack_data->ipython) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\paulk\.pyenv\pyenv-win\versions\3.13.3\lib\site-packages (from stack_data->ipython) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\paulk\.pyenv\pyenv-win\versions\3.13.3\lib\site-packages (from stack_data->ipython) (0.2.3)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\paulk\.pyenv\pyenv-win\versions\3.13.3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\paulk\.pyenv\pyenv-win\versions\3.13.3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\paulk\.pyenv\pyenv-win\versions\3.13.3\Lib\site-packages)
#
# [notice] A new release of pip is available: 25.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from matplotlib.pyplot import figure, rc
import numpy as np
import matplotlib.pyplot as plt
import time
from ipywidgets import interact
import ipywidgets as widgets
from IPython.display import display


def logistic_growth_function(r, x):
    return r*x*(1-x)
    # 
    # N' = r*N*(K-N)
    # Entdimensionalisierung: neue Variable x=N/K 
    # 
def sine_growth_function (r,x):
    return r*np.sin(np.pi*x)/4
    
def iterate_logistic_growth_function(n_iterations, r, x_0):
    if type(x_0) == float or type(x_0) == np.longdouble:
        values = np.zeros(n_iterations, dtype=np.longdouble)
    else:
        values = np.zeros((n_iterations,x_0.shape[-1]), dtype=np.longdouble)
    values[0] = x_0
    for i in range(1, n_iterations):
        values[i] = logistic_growth_function(r, values[i-1])
    return values

def iterate_sine_growth_function(n_iterations, r, x_0):
    if type(x_0) == float or type(x_0) == np.longdouble:
        values = np.zeros(n_iterations, dtype=np.longdouble)
    else:
        values = np.zeros((n_iterations,x_0.shape[-1]), dtype=np.longdouble)
    values[0] = x_0
    for i in range(1, n_iterations):
        values[i] = sine_growth_function(r, values[i-1])
    return values


def plot_cobweb(r=0.1, x0=0.2, tmax=100, growth_function=logistic_growth_function, n_times_function_applied=1):
    x = np.linspace(0,1,500)
    fig = plt.figure(figsize=(15,8), dpi=100)
    ax=fig.add_subplot(111)
    def final_map(r,x):
        result = growth_function(r,x)
        for i in range(n_times_function_applied-1):
            result = growth_function(r, result)
        return result
    ax.plot(x, final_map(r,x), c='#444444', lw=2)
    ax.plot(x,x, c='#444444', lw=2)

    px, py = np.empty((2, tmax+1, 2))
    px[0] = x0
    py[0] = 0
    for n in range(1, tmax, 2):
        px[n] = px[n-1]
        py[n] = final_map(r, px[n-1])
        px[n+1] = py[n]
        py[n+1] = py[n]

    ax.plot(px, py, c="b", alpha=0.7)
    ax.set_xlim((0,1))
    ax.set_ylim((0,1))
    ax.set_xlabel("Anfangspopulationsgröße x")
    ax.set_ylabel("Endwert Populationsgröße $rx(1-x)$")
    ax.set_title('$x_0 = {:.1}, r = {:.7}$'.format(x0*1.,r*1.))

def plot_orbit_diagram_old(r_values=(3.0, 3.86),r_value_distance=0.0001, x_value_distance=0.001, n_iterations=10, labelsize=0.001, figsize=(20,10), dpi=100):
    all_r_values = np.arange(*r_values,r_value_distance)
    all_x_values = np.arange(0,1,x_value_distance)
    
    scatter_points = np.zeros((all_r_values.shape[-1], all_x_values.shape[-1]))
    for i,r in enumerate(all_r_values):
        scatter_points[i] = iterate_logistic_growth_function(n_iterations, r, all_x_values)[-1,:]
    
    fig, ax = plt.subplots(figsize=figsize, dpi=dpi)
    
    ax.scatter(np.repeat(all_r_values, all_x_values.shape[-1]), scatter_points.flatten(), s=labelsize, marker=".")
    ax.set_xlim(r_values)
    ax.set_ylim(0,1)
    ax.set_xlabel("r")
    ax.set_ylabel("Werte von x für t = {:}".format(n_iterations))
    ax.set_title('$r \\in ({:.4},{:.4})$'.format(r_values[0]*1.,r_values[1]*1.))
    return ax
def plot_orbit_diagram(r_values=(3.0, 3.86),r_value_distance=0.0001, x0=0.5, n_iterations_to_plot_from=100, n_iterations_to_plot_until=200, labelsize=0.001, figsize=(20,10), dpi=100, discrete_map=iterate_logistic_growth_function, color="tab:blue", ax=None):
    all_r_values = np.arange(*r_values,r_value_distance)
    
    scatter_points = np.zeros((all_r_values.shape[-1], -n_iterations_to_plot_from+n_iterations_to_plot_until))
    for i,r in enumerate(all_r_values):
        scatter_points[i] = discrete_map(n_iterations_to_plot_until, r, x0)[n_iterations_to_plot_from:n_iterations_to_plot_until]
    if ax == None:
        fig, ax = plt.subplots(figsize=figsize, dpi=dpi)
    
    ax.scatter(np.repeat(all_r_values, -n_iterations_to_plot_from+n_iterations_to_plot_until), scatter_points.flatten(), s=labelsize, marker=".", c=color)
    ax.set_xlim(r_values)
    ax.set_ylim(0,1)
    ax.set_xlabel("r")
    ax.set_ylabel("Werte von x für $t \\in ({:},{:})$".format(n_iterations_to_plot_from, n_iterations_to_plot_until))
    ax.set_title('$x_0 = {:.1}, r \\in ({:.4},{:.4})$'.format(x0*1.0,r_values[0]*1.,r_values[1]*1.))
    return ax

def plot_trajectory(r=3.0, x0=0.5, n_iterations=100, figsize=(20,10), dpi=100):
    plt.figure(figsize=figsize, dpi=dpi)
    x = np.arange(1, n_iterations+1)
    y = iterate_logistic_growth_function(n_iterations, r, np.longdouble(x0))
    
    plt.plot(x[:n_iterations], y[:n_iterations])
    plt.xlabel("Zeitschritte t")
    plt.ylabel("Populationsgröße x")
    plt.ylim(0,1)
    plt.xlim(0,n_iterations)
    plt.title('$x_0 = {:.1}, r = {:.4}$'.format(x0*1.,r*1.))

# %%
# %matplotlib widget

# %%
n_iterations = 100
x0 = 0.5
figsize = (20,10)
dpi = 100
r_init = 0

fig, ax = plt.subplots()

x = np.arange(0,n_iterations)
y = iterate_logistic_growth_function(n_iterations, r_init, np.longdouble(x0))

plot, = ax.plot(x, y)
ax.set_xlabel("Zeitschritte t")
ax.set_ylabel("Populationsgröße x")
ax.set_ylim(0,1)
ax.set_xlim(0,n_iterations)


def plot_trajectory(r):
    y = iterate_logistic_growth_function(n_iterations, r, np.longdouble(x0))
    #plt.plot(x[:n_iterations], y[:n_iterations])
    plot.set_ydata(y)
    fig.canvas.draw()
interact(plot_trajectory, r=widgets.FloatSlider(value=0.0,min=0.0, max=4.0, step=0.001,description="r",disabled=False,continuous_update=True,orientation="horizontal",readout=True, readout_format=".3f",layout=widgets.Layout(width='1000px')))
plt.show()
# Out:
# interactive(children=(FloatSlider(value=0.0, description='r', layout=Layout(width='1000px'), max=4.0, readout_…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plot_trajectory(r=0.5, x0=0.5, n_iterations=100)

# %%
plot_trajectory(r=1.0, x0=0.5, n_iterations=100)

# %%
plot_trajectory(r=1.1, x0=0.5, n_iterations=100)

# %%
plot_trajectory(r=1.5, x0=0.5, n_iterations=100)

# %%
plot_trajectory(r=2.0, x0=0.5, n_iterations=100)

# %%
plot_trajectory(r=2.5, x0=0.5, n_iterations=100)

# %%
plot_trajectory(r=3.0, x0=0.5, n_iterations=100)

# %%
plot_trajectory(r=3.0, x0=0.5, n_iterations=500)

# %%
plot_trajectory(r=3.25, x0=0.5, n_iterations=100)

# %%
plot_trajectory(r=3.5, x0=0.5, n_iterations=100)

# %%
plot_trajectory(r=3.56, x0=0.5, n_iterations=100)

# %%
plot_trajectory(r=3.566, x0=0.5, n_iterations=100)

# %%
plot_trajectory(r=3.569, x0=0.5, n_iterations=100)

# %%
plot_trajectory(r=3.8, x0=0.5, n_iterations=100)

# %%
plot_trajectory(r=3.8282, x0=0.5, n_iterations=300)

# %%
plot_trajectory(r=3.84, x0=0.5, n_iterations=100)

# %%
plot_cobweb(r=0.9,x0=0.5)

# %%
plot_cobweb(r=1.5,x0=0.5)

# %%
plot_cobweb(r=2.5,x0=0.5)

# %%
plot_cobweb(r=3.1,x0=0.5)

# %%
plot_cobweb(r=3.5,x0=0.5)

# %%
plot_cobweb(r=3.55,x0=0.5)

# %%
plot_cobweb(r=3.8,x0=0.5, tmax=300, n_times_function_applied=1)

# %%
plot_cobweb(r=3.8282,x0=0.5, tmax=300)

# %%
plot_cobweb(r=3.83,x0=0.5, tmax=300, n_times_function_applied=1)

# %%
plot_cobweb(r=3.9,x0=0.5, tmax=100)

# %%
plot_cobweb(r=3.9,x0=0.5, tmax=1000)

# %%
plot_cobweb(r=3.9,x0=0.5, tmax=5000)

# %%
ax = plot_orbit_diagram(r_values=(0, 3),r_value_distance=0.0001, x0=0.5, n_iterations_to_plot_from=400, n_iterations_to_plot_until=500, labelsize=0.001)

# %%
ax = plot_orbit_diagram(r_values=(0, 3.4),r_value_distance=0.0001, x0=0.5, n_iterations_to_plot_from=400, n_iterations_to_plot_until=500, labelsize=0.001)

# %%
ax = plot_orbit_diagram(r_values=(0, 3.5),r_value_distance=0.0001, x0=0.5, n_iterations_to_plot_from=400, n_iterations_to_plot_until=500, labelsize=0.001)

# %%
ax = plot_orbit_diagram(r_values=(0, 4),r_value_distance=0.0001, x0=0.5, n_iterations_to_plot_from=100, n_iterations_to_plot_until=200, labelsize=0.001)

# %%
ax = plot_orbit_diagram(r_values=(3.4, 4),r_value_distance=0.0001, x0=0.5, n_iterations_to_plot_from=100, n_iterations_to_plot_until=200, labelsize=0.004)
import matplotlib.patches as patches
rect = patches.Rectangle((3.847, 0.13), 0.01, 0.035, linewidth=1, edgecolor='r', facecolor='none')
patch = ax.add_patch(rect)
# Out:
# C:\Users\paulk\AppData\Local\Temp\ipykernel_26392\621835958.py:8: RuntimeWarning: overflow encountered in scalar multiply
#   return r*x*(1-x)

# %%
ax = plot_orbit_diagram(r_values=(3.847, 3.857),r_value_distance=0.0000001, x0=0.5, n_iterations_to_plot_from=200, n_iterations_to_plot_until=300, labelsize=0.0002)
plt.ylim(0.13,0.175)
rect = patches.Rectangle((3.85394, 0.16625), -3.85394+3.85409, -0.16625+0.16775, linewidth=1, edgecolor='r', facecolor='none')
patch = ax.add_patch(rect)

# %%
plot_orbit_diagram(r_values=(3.85394, 3.85409),r_value_distance=0.00000001, x0=0.5, n_iterations_to_plot_from=2000, n_iterations_to_plot_until=2300, labelsize=0.02)
lims = plt.ylim(0.16625,0.16775)

# %% [markdown]
# ## Universalität und Feigenbaumkonstante

# %% [markdown]
# Abbildung $x_{t+1}=\frac{r}{4} \sin(\pi x_t)$ an. (immer orange)

# %%
ax=plot_orbit_diagram(r_values=(0, 4),r_value_distance=0.0001, x0=0.5, n_iterations_to_plot_from=100, n_iterations_to_plot_until=200, labelsize=0.001, color="tab:orange", discrete_map=iterate_sine_growth_function)

# %% [markdown]
# im Vergleich zu $rx(1-x)$

# %%
ax = plot_orbit_diagram(r_values=(0, 4),r_value_distance=0.0001, x0=0.5, n_iterations_to_plot_from=100, n_iterations_to_plot_until=200, labelsize=0.001)
plot_orbit_diagram(r_values=(0, 4),r_value_distance=0.0001, x0=0.5, n_iterations_to_plot_from=100, n_iterations_to_plot_until=200, labelsize=0.001, discrete_map=iterate_sine_growth_function, color="tab:orange", ax=ax)
# Out:
# <Axes: title={'center': '$x_0 = 0.5, r \\in (0.0,4.0)$'}, xlabel='r', ylabel='Werte von x für $t \\in (100,200)$'>

# %%
ax = plot_orbit_diagram(r_values=(2.7, 4),r_value_distance=0.0001, x0=0.5, n_iterations_to_plot_from=100, n_iterations_to_plot_until=200, labelsize=0.001)
plot_orbit_diagram(r_values=(2.7, 4),r_value_distance=0.0001, x0=0.5, n_iterations_to_plot_from=100, n_iterations_to_plot_until=200, labelsize=0.001, discrete_map=iterate_sine_growth_function, color="tab:orange", ax=ax)
# Out:
# <Axes: title={'center': '$x_0 = 0.5, r \\in (2.7,4.0)$'}, xlabel='r', ylabel='Werte von x für $t \\in (100,200)$'>

# %%
ax = plot_orbit_diagram(r_values=(2.9, 3.6),r_value_distance=0.0001, x0=0.5, n_iterations_to_plot_from=1000, n_iterations_to_plot_until=1100, labelsize=0.001)
vals = [3.,3.449, 3.543, 3.564]
ax.vlines(vals, 0,1, colors="r")
old_ticks =[round(a, 4) for a in ax.get_xticks()]
old_labels = old_ticks.copy()
old_ticks.extend(vals)
old_labels.extend(["$r_1$", "$r_2$", "$r_3$", "$r_4$"])
ticks = ax.set_xticks(old_ticks, old_labels)
